# %% [markdown]
# <a href="https://colab.research.google.com/github/sjune0110/IQC/blob/main/IQC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json

credentials = ["osjun11@gmail.com", "Os1935!@!"]
with open(".brain_credentials", "w") as f:
    json.dump(credentials, f)

# %%
# !rm -rf Alpha-Automation
# !git clone https://github.com/KIRANBADAKURAVA/Alpha-Automation.git
# Out:
# Cloning into 'Alpha-Automation'...
# remote: Enumerating objects: 29, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 29 (delta 9), reused 22 (delta 8), pack-reused 0 (from 0)
# Receiving objects: 100% (29/29), 1.18 MiB | 4.66 MiB/s, done.
# Resolving deltas: 100% (9/9), done.

# %%
# %cd Alpha-Automation
# Out:
# /content/Alpha-Automation

# %%
# %cd alpha_creation_engine-main
# !ls
# Out:
# /content/Alpha-Automation/alpha_creation_engine-main
#  ace_lib.py	    'diff datasets.ipynb'   how_to_use.ipynb   requirements.txt
#  automation1.ipynb  'glb .ipynb'	    __pycache__        usa.ipynb
#  automation.ipynb    helpful_functions.py   README.md	      'usa no filter.ipynb'

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 14.5 MB/s eta 0:00:00
# ...

# %%
import json

credentials = ["osjun11@gmail.com", "Os1935!@!"]
with open(".brain_credentials", "w") as f:
    json.dump(credentials, f)

# %% [markdown]
# 밑작업 완료 아래부터는 how to use file 참고

# %%
import ace_lib as ace
import helpful_functions as hf
import pandas as pd
import requests
import plotly.express as px

# %%
s = ace.start_session()
# Out:
# Email:
# osjun11@gmail.com
# Password:··········

# %%
datasets_df = hf.get_datasets(s) # by default we load all datasets USA TOP3000 delay 1
datasets_df.head() # DataFrame.head() shows first 5 rows of the dataframe
# Out:
#              id                                 name  \
# 0      analyst4     Analyst Estimate Data for Equity
# 1  fundamental2                     Report Footnotes
# 2  fundamental6  Company Fundamental Data for Equity
# 3       model16                   Fundamental Scores
# 4       model51              Systematic Risk Metrics
#
#                                          description  \
# 0  This dataset provides details and aggregations...
# 1  This dataset holds fundamental items included ...
# 2  Fundamental database covers most of the world'...
# 3  This dataset ranks stocks based on fundamental...
# 4  This is a risk-model data offering several met...
#
#                                        category  \
# 0          {'id': 'analyst', 'name': 'Analyst'}
# 1  {'id': 'fundamental', 'name': 'Fundamental'}
# 2  {'id': 'fundamental', 'name': 'Fundamental'}
# 3              {'id': 'model', 'name': 'Model'}
# 4              {'id': 'model', 'name': 'Model'}
#
# ...
